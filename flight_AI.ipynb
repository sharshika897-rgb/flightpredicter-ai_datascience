# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# accessing data from drive

# %%
import pandas as pd
import numpy as np

file_path = "/content/drive/MyDrive/flight_pricing_dataset.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# checking the properties of dataset like shape,columns in it and properties of the data like dtype and values.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 100000
# Columns: 18

# %%
df.head()
df.dtypes
# Out:
# Flight_ID                object
# Airline                  object
# Source                   object
# Destination              object
# Departure_Date           object
# Departure_Time           object
# Arrival_Time             object
# Duration                 object
# Total_Stops              object
# Distance_km              object
# Travel_Class             object
# Days_Before_Departure    object
# Season                   object
# Weekday                  object
# Aircraft_Type            object
# Booking_Channel          object
# Passenger_Count          object
# Price                    object
# dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['Flight_ID', 'Airline', 'Source', 'Destination', 'Departure_Date', 'Departure_Time', 'Arrival_Time', 'Duration', 'Total_Stops', 'Distance_km', 'Travel_Class', 'Days_Before_Departure', 'Season', 'Weekday', 'Aircraft_Type', 'Booking_Channel', 'Passenger_Count', 'Price']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Flight_ID              100000 non-null  object
#  1   Airline                95120 non-null   object
#  2   Source                 95085 non-null   object
#  3   Destination            95119 non-null   object
#  4   Departure_Date         95073 non-null   object
#  5   Departure_Time         95132 non-null   object
#  6   Arrival_Time           95211 non-null   object
#  7   Duration               94958 non-null   object
#  8   Total_Stops            95095 non-null   object
#  9   Distance_km            95077 non-null   object
#  10  Travel_Class           95137 non-null   object
#  11  Days_Before_Departure  95216 non-null   object
#  12  Season                 95224 non-null   object
#  13  Weekday                95280 non-null   object
#  14  Aircraft_Type          95148 non-null   object
#  15  Booking_Channel        95038 non-null   object
#  16  Passenger_Count        95174 non-null   object
#  17  Price                  94947 non-null   object
# dtypes: object(18)
# memory usage: 13.7+ MB

# %%
df.describe(include="all").T
# Out:
#                         count unique                 top   freq
# Flight_ID              100000  98039            FL119204      3
# Airline                 95120     39  Singapore Airlines   7864
# Source                  95085     54             Chennai   3519
# Destination             95119     54                 Goa   3503
# Departure_Date          95073    730          2025-04-05    168
# Departure_Time          95132    576               09:50    242
# Arrival_Time            95211   2880               06:24     64
# Duration                94958   5111              1h 10m    377
# Total_Stops             95095      6                   1  26710
# Distance_km             95077  59484                 150    590
# Travel_Class            95137      4             Economy  64867
# Days_Before_Departure   95216    341                   0   3554
# Season                  95224      4             Monsoon  31808
# Weekday                 95280      7              Sunday  13809
# Aircraft_Type           95148      8         Airbus A320  20450
# Booking_Channel         95038      5             Website  30696
# Passenger_Count         95174     12                   1  39079
# Price                   94947  78725              200000   8989

# %% [markdown]
# checking missing values and duplicate data entries and invalid data entries

# %%
missing = df.isnull().sum()

print(missing)
# Out:
# Flight_ID                   0
# Airline                  4880
# Source                   4915
# Destination              4881
# Departure_Date           4927
# Departure_Time           4868
# Arrival_Time             4789
# Duration                 5042
# Total_Stops              4905
# Distance_km              4923
# Travel_Class             4863
# Days_Before_Departure    4784
# Season                   4776
# Weekday                  4720
# Aircraft_Type            4852
# Booking_Channel          4962
# Passenger_Count          4826
# Price                    5053
# dtype: int64

# %%
missing_percentage = (
    df.isnull().sum() / len(df) * 100
).sort_values(ascending=False)

print(missing_percentage)
# Out:
# Price                    5.053
# Duration                 5.042
# Booking_Channel          4.962
# Departure_Date           4.927
# Distance_km              4.923
# Source                   4.915
# Total_Stops              4.905
# Destination              4.881
# Airline                  4.880
# Departure_Time           4.868
# Travel_Class             4.863
# Aircraft_Type            4.852
# Passenger_Count          4.826
# Arrival_Time             4.789
# Days_Before_Departure    4.784
# Season                   4.776
# Weekday                  4.720
# Flight_ID                0.000
# dtype: float64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 1961

# %%
print("Duplicate Flight IDs:", df["Flight_ID"].duplicated().sum())
# Out:
# Duplicate Flight IDs: 1961

# %%
print("AIRLINES")
print(df["Airline"].value_counts())

print("\nSOURCE")
print(df["Source"].value_counts())

print("\nDESTINATION")
print(df["Destination"].value_counts())

print("\nTRAVEL CLASS")
print(df["Travel_Class"].value_counts())

print("\nTOTAL STOPS")
print(df["Total_Stops"].value_counts())

print("\nSEASON")
print(df["Season"].value_counts())

print("\nWEEKDAY")
print(df["Weekday"].value_counts())

print("\nAIRCRAFT TYPE")
print(df["Aircraft_Type"].value_counts())

print("\nBOOKING CHANNEL")
print(df["Booking_Channel"].value_counts())
# Out:
# AIRLINES
# Airline
# Singapore Airlines    7864
# Etihad Airways        7802
# Lufthansa             7786
# Emirates              7722
# Thai Airways          7708
# Qatar Airways         7667
# British Airways       7598
# Vistara               5649
# Air India             4895
# Indigo                4677
# AirAsia India         4649
# GoFirst               4630
# SpiceJet              4602
# air india              740
# AIR INDIA              713
# thai airways           564
# SINGAPORE AIRLINES     546
# BRITISH AIRWAYS        536
# lufthansa              527
# singapore airlines     521
# emirates               515
# LUFTHANSA              513
# etihad airways         505
# QATAR AIRWAYS          505
# british airways        505
# qatar airways          501
# EMIRATES               497
# THAI AIRWAYS           482
# ETIHAD AIRWAYS         467
# vistara                388
# VISTARA                378
# GOFIRST                327
# airasia india          320
# AIRASIA INDIA          318
# spicejet               309
# SPICEJET               305
# indigo                 300
# INDIGO                 296
# gofirst                293
# Name: count, dtype: int64
#
# SOURCE
# Source
# Chennai              3519
# Pune                 3506
# New York             3502
# Singapore            3489
# Doha                 3482
# Bangkok              3480
# Hyderabad            3473
# Dubai                3467
# Ahmedabad            3466
# Bangalore            3452
# Frankfurt            3451
# Mumbai               3434
# Jaipur               3433
# Sydney               3426
# London               3411
# Kolkata              3375
# Delhi                3353
# Goa                  3351
# GOI                   993
# Jaipur Airport        965
# Ahmedabad Airport     957
# DEL                   954
# BKK                   952
# BOM                   943
# BLR                   942
# DXB                   941
# LHR                   936
# Kolkata Airport       933
# Dubai Airport         928
# MAA                   926
# HYD                   926
# Mumbai Airport        925
# JFK                   925
# SIN                   923
# New York Airport      919
# Delhi Airport         919
# Hyderabad Airport     919
# Pune Airport          912
# London Airport        912
# Sydney Airport        911
# AMD                   910
# Frankfurt Airport     908
# Bangalore Airport     907
# Chennai Airport       901
# PNQ                   899
# CCU                   898
# Singapore Airport     896
# Bangkok Airport       895
# SYD                   895
# DOH                   893
# JAI                   884
# Goa Airport           866
# Doha Airport          852
# FRA                   850
# Name: count, dtype: int64
#
# DESTINATION
# Destination
# Goa                  3503
# Bangkok              3493
# Pune                 3488
# Hyderabad            3487
# Ahmedabad            3472
# London               3451
# Mumbai               3436
# Doha                 3426
# Delhi                3424
# Chennai              3414
# Bangalore            3411
# Kolkata              3411
# Singapore            3402
# Dubai                3393
# Sydney               3392
# Frankfurt            3380
# Jaipur               3363
# New York             3306
# BLR                   981
# Dubai Airport         974
# Goa Airport           970
# New York Airport      970
# Singapore Airport     968
# GOI                   955
# Bangkok Airport       953
# DEL                   953
# JAI                   950
# MAA                   950
# Jaipur Airport        948
# DXB                   942
# BOM                   942
# JFK                   941
# Bangalore Airport     941
# CCU                   941
# Mumbai Airport        936
# Doha Airport          935
# Chennai Airport       933
# SYD                   932
# Delhi Airport         929
# London Airport        926
# Sydney Airport        926
# LHR                   922
# AMD                   922
# BKK                   917
# FRA                   916
# Pune Airport          908
# DOH                   908
# Kolkata Airport       906
# HYD                   894
# PNQ                   894
# Frankfurt Airport     887
# Ahmedabad Airport     873
# SIN                   866
# Hyderabad Airport     858
# Name: count, dtype: int64
#
# TRAVEL CLASS
# Travel_Class
# Economy            64867
# Premium Economy    15078
# Business           11249
# First               3943
# Name: count, dtype: int64
#
# TOTAL STOPS
# Total_Stops
# 1           26710
# 0           22887
# 1 stop      17673
# non-stop    15433
# 2            7358
# 2 stops      5034
# Name: count, dtype: int64
#
# SEASON
# Season
# Monsoon    31808
# Summer     24116
# Winter     23286
# Autumn     16014
# Name: count, dtype: int64
#
# WEEKDAY
# Weekday
# Sunday       13809
# Saturday     13632
# Tuesday      13610
# Wednesday    13590
# Monday       13548
# Thursday     13547
# Friday       13544
# Name: count, dtype: int64
#
# AIRCRAFT TYPE
# Aircraft_Type
# Airbus A320              20450
# Boeing 777               13520
# Airbus A350              13446
# Boeing 787 Dreamliner    13436
# Airbus A380              13336
# Airbus A321               7032
# Boeing 737                6969
# ATR 72                    6959
# Name: count, dtype: int64
#
# BOOKING CHANNEL
# Booking_Channel
# Website            30696
# Mobile App         28379
# Travel Agent       17048
# Third-Party        13321
# Airport Counter     5594
# Name: count, dtype: int64

# %% [markdown]
# creating a list of numerical columns for clarity

# %%
numerical_columns = [
    "Distance_km",
    "Days_Before_Departure",
    "Passenger_Count",
    "Price"
]

df[numerical_columns].describe()
# Out:
#        Distance_km Days_Before_Departure Passenger_Count   Price
# count        95077                 95216           95174   94947
# unique       59484                   341              12   78725
# top            150                     0               1  200000
# freq           590                  3554           39079    8989

# %% [markdown]
# fixing the null values and invalid ones in duration ,departure date, arrival time

# %%
print(df["Duration"].head(30).to_string())
# Out:
# 0         1.67
# 1       0h 45m
# 2        14.80
# 3       3h 11m
# 4        13.93
# 5      16h 47m
# 6       1h 28m
# 7       5h 27m
# 8      17h 04m
# 9       3h 20m
# 10     177 min
# 11         NaN
# 12      0h 59m
# 13         NaN
# 14      2h 02m
# 15     155 min
# 16     22h 40m
# 17     18h 45m
# 18      6h 04m
# 19        1.98
# 20      2h 38m
# 21         NaN
# 22        4.38
# 23     900 min
# 24    1039 min
# 25      0h 49m
# 26      3h 27m
# 27     20h 26m
# 28      2h 16m
# 29      5h 41m

# %%
print(df["Duration"].unique()[:50])
# Out:
# ['1.67' '0h 45m' '14.80' '3h 11m' '13.93' '16h 47m' '1h 28m' '5h 27m'
#  '17h 04m' '3h 20m' '177 min' nan '0h 59m' '2h 02m' '155 min' '22h 40m'
#  '18h 45m' '6h 04m' '1.98' '2h 38m' '4.38' '900 min' '1039 min' '0h 49m'
#  '3h 27m' '20h 26m' '2h 16m' '5h 41m' '3h 16m' '4h 52m' '1346 min'
#  '146 min' '423 min' '14h 29m' '137 min' '14h 22m' '959 min' '660 min'
#  '71 min' '4h 58m' '2h 14m' '339 min' '3h 33m' '17h 15m' '10.83' '2h 39m'
#  '8h 33m' '14h 21m' '5h 16m' '1h 09m']

# %% [markdown]
# fixing null, invaid data entries in departure time and arrival time as they have diffrent way to represent time and is not uniform

# %%
print(df["Departure_Date"].head(20).to_string())
# Out:
# 0     2025-08-02
# 1     2025-06-05
# 2     2025-02-11
# 3     2025-04-19
# 4     2026-07-05
# 5     2025-06-25
# 6     2025-02-16
# 7     2026-10-08
# 8     2025-10-13
# 9     2026-03-30
# 10    2025-01-12
# 11    2025-04-29
# 12    2026-02-05
# 13    2026-05-24
# 14    2026-06-24
# 15    2025-03-28
# 16    2025-07-08
# 17    2026-10-10
# 18    2025-03-22
# 19    2025-06-25

# %%
print(df["Departure_Date"].dtype)
# Out:
# object

# %%
print("Departure:")
print(df["Departure_Time"].head(20).to_string())

print("\nArrival:")
print(df["Arrival_Time"].head(20).to_string())
# Out:
# Departure:
# 0      8:10 PM
# 1        12:10
# 2      5:05 PM
# 3        07:05
# 4     10:40 PM
# 5      4:15 AM
# 6      1:35 AM
# 7      9:55 AM
# 8      5:45 AM
# 9      8:15 AM
# 10       13:30
# 11       23:30
# 12       22:50
# 13       19:25
# 14       13:50
# 15       15:05
# 16     4:50 PM
# 17     5:20 AM
# 18    10:15 PM
# 19     7:25 PM
#
# Arrival:
# 0        21:50
# 1        12:55
# 2      7:53 AM
# 3     10:16 AM
# 4        12:36
# 5        21:02
# 6      3:02 AM
# 7      3:21 PM
# 8        22:49
# 9     11:35 AM
# 10       16:26
# 11       04:04
# 12       23:48
# 13     4:54 PM
# 14       15:51
# 15     5:39 PM
# 16       15:29
# 17       00:05
# 18     4:19 AM
# 19       21:23

# %% [markdown]
# creating df_clean to store cleaned dataframe

# %%
df_clean = df.copy()

# %% [markdown]
# removing duplicate entries from the dataframe

# %%
duplicate_count = df_clean.duplicated().sum()

print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 1961

# %%
df_clean = df_clean.drop_duplicates()

print("Shape after removing duplicates:", df_clean.shape)
# Out:
# Shape after removing duplicates: (98039, 18)

# %%
categorical_columns = [
    "Airline",
    "Source",
    "Destination",
    "Travel_Class",
    "Season",
    "Weekday",
    "Aircraft_Type",
    "Booking_Channel"
]

for column in categorical_columns:
    df_clean[column] = (
        df_clean[column]
        .astype("string")
        .str.strip()
    )

# %% [markdown]
# cleaning airline column that have same airline with diffrent font styles

# %%
print(df_clean["Airline"].value_counts().head(20))
# Out:
# Airline
# Singapore Airlines    7723
# Etihad Airways        7653
# Lufthansa             7646
# Emirates              7569
# Thai Airways          7549
# Qatar Airways         7521
# British Airways       7436
# Vistara               5531
# Air India             4780
# Indigo                4594
# AirAsia India         4555
# GoFirst               4533
# SpiceJet              4514
# air india              724
# AIR INDIA              694
# thai airways           555
# SINGAPORE AIRLINES     536
# BRITISH AIRWAYS        525
# lufthansa              515
# singapore airlines     513
# Name: count, dtype: Int64

# %%
airline_values = (
    df_clean["Airline"]
    .dropna()
    .unique()
)

print(sorted(airline_values))
# Out:
# ['AIR INDIA', 'AIRASIA INDIA', 'Air India', 'AirAsia India', 'BRITISH AIRWAYS', 'British Airways', 'EMIRATES', 'ETIHAD AIRWAYS', 'Emirates', 'Etihad Airways', 'GOFIRST', 'GoFirst', 'INDIGO', 'Indigo', 'LUFTHANSA', 'Lufthansa', 'QATAR AIRWAYS', 'Qatar Airways', 'SINGAPORE AIRLINES', 'SPICEJET', 'Singapore Airlines', 'SpiceJet', 'THAI AIRWAYS', 'Thai Airways', 'VISTARA', 'Vistara', 'air india', 'airasia india', 'british airways', 'emirates', 'etihad airways', 'gofirst', 'indigo', 'lufthansa', 'qatar airways', 'singapore airlines', 'spicejet', 'thai airways', 'vistara']

# %%
df_clean["Airline"] = (
    df_clean["Airline"]
    .str.lower()
    .str.strip()
    .str.title()
)

# %%
print(df_clean["Airline"].value_counts())
# Out:
# Airline
# Singapore Airlines    8772
# Lufthansa             8663
# Etihad Airways        8614
# Thai Airways          8576
# Emirates              8570
# Qatar Airways         8503
# British Airways       8456
# Vistara               6287
# Air India             6198
# Airasia India         5182
# Indigo                5176
# Gofirst               5142
# Spicejet              5112
# Name: count, dtype: Int64

# %% [markdown]
# cleaning source,destination and travel class

# %%
df_clean["Source"] = (
    df_clean["Source"]
    .str.lower()
    .str.strip()
    .str.title()
)

df_clean["Destination"] = (
    df_clean["Destination"]
    .str.lower()
    .str.strip()
    .str.title()
)

# %%
print("Sources:")
print(df_clean["Source"].value_counts())

print("\nDestinations:")
print(df_clean["Destination"].value_counts())
# Out:
# Sources:
# Source
# Chennai              3456
# Pune                 3431
# Doha                 3427
# Singapore            3426
# New York             3412
# Hyderabad            3406
# Bangkok              3405
# Dubai                3396
# Frankfurt            3393
# Ahmedabad            3391
# Bangalore            3382
# Jaipur               3370
# Mumbai               3364
# Sydney               3363
# London               3332
# Kolkata              3315
# Delhi                3299
# Goa                  3283
# Goi                   965
# Jaipur Airport        945
# Bkk                   937
# Del                   935
# Dxb                   932
# Ahmedabad Airport     930
# Bom                   925
# Kolkata Airport       919
# Blr                   918
# Lhr                   916
# Dubai Airport         914
# Jfk                   913
# Maa                   910
# Hyd                   908
# Sin                   904
# Mumbai Airport        903
# New York Airport      902
# Delhi Airport         900
# Hyderabad Airport     900
# Pune Airport          898
# Frankfurt Airport     894
# Amd                   894
# London Airport        894
# Sydney Airport        893
# Bangalore Airport     888
# Syd                   881
# Pnq                   879
# Bangkok Airport       879
# Ccu                   879
# Chennai Airport       878
# Doh                   877
# Singapore Airport     877
# Jai                   866
# Goa Airport           847
# Doha Airport          841
# Fra                   832
# Name: count, dtype: Int64
#
# Destinations:
# Destination
# Bangkok              3427
# Goa                  3426
# Hyderabad            3420
# Pune                 3413
# Ahmedabad            3411
# London               3377
# Doha                 3366
# Delhi                3364
# Bangalore            3354
# Mumbai               3350
# Chennai              3347
# Kolkata              3333
# Singapore            3324
# Dubai                3322
# Frankfurt            3320
# Sydney               3316
# Jaipur               3303
# New York             3248
# Dubai Airport         959
# Singapore Airport     954
# Blr                   953
# New York Airport      951
# Goa Airport           951
# Bangkok Airport       941
# Goi                   932
# Del                   930
# Jai                   929
# Jaipur Airport        928
# Jfk                   928
# Maa                   925
# Dxb                   925
# Bom                   923
# Bangalore Airport     923
# Ccu                   923
# Mumbai Airport        920
# Doha Airport          916
# Chennai Airport       914
# London Airport        914
# Syd                   911
# Delhi Airport         911
# Sydney Airport        910
# Lhr                   910
# Amd                   905
# Bkk                   898
# Doh                   894
# Pune Airport          894
# Fra                   892
# Kolkata Airport       892
# Hyd                   873
# Pnq                   873
# Frankfurt Airport     872
# Ahmedabad Airport     862
# Sin                   854
# Hyderabad Airport     844
# Name: count, dtype: Int64

# %%
print(df_clean["Travel_Class"].value_counts(dropna=False))
# Out:
# Travel_Class
# Economy            63604
# Premium Economy    14770
# Business           11030
# <NA>                4763
# First               3872
# Name: count, dtype: Int64

# %%
df_clean["Travel_Class"] = (
    df_clean["Travel_Class"]
    .str.lower()
    .str.strip()
    .str.title()
)

# %%
print(df_clean["Travel_Class"].value_counts(dropna=False))
# Out:
# Travel_Class
# Economy            63604
# Premium Economy    14770
# Business           11030
# <NA>                4763
# First               3872
# Name: count, dtype: Int64

# %%
df_clean["Departure_Date"] = pd.to_datetime(
    df_clean["Departure_Date"],
    errors="coerce"
)

# %%
print(df_clean["Departure_Date"].dtype)
# Out:
# datetime64[ns]

# %%
df_clean["Journey_Year"] = (
    df_clean["Departure_Date"].dt.year
)

# %%
df_clean["Journey_Month"] = (
    df_clean["Departure_Date"].dt.month
)

# %%
df_clean["Journey_Day"] = (
    df_clean["Departure_Date"].dt.day
)

# %%
df_clean["Journey_DayOfWeek"] = (
    df_clean["Departure_Date"].dt.dayofweek
)

# %%
df_clean[
    [
        "Departure_Date",
        "Journey_Year",
        "Journey_Month",
        "Journey_Day",
        "Journey_DayOfWeek"
    ]
].head(10)
# Out:
#   Departure_Date  Journey_Year  Journey_Month  Journey_Day  Journey_DayOfWeek
# 0     2025-08-02        2025.0            8.0          2.0                5.0
# 1     2025-06-05        2025.0            6.0          5.0                3.0
# 2     2025-02-11        2025.0            2.0         11.0                1.0
# 3     2025-04-19        2025.0            4.0         19.0                5.0
# 4     2026-07-05        2026.0            7.0          5.0                6.0
# 5     2025-06-25        2025.0            6.0         25.0                2.0
# 6     2025-02-16        2025.0            2.0         16.0                6.0
# 7     2026-10-08        2026.0           10.0          8.0                3.0
# 8     2025-10-13        2025.0           10.0         13.0                0.0
# 9     2026-03-30        2026.0            3.0         30.0                0.0

# %%
def convert_time_to_minutes(value):

    if pd.isna(value):
        return np.nan

    value = str(value).strip()

    try:
        time_value = pd.to_datetime(value)

        return (
            time_value.hour * 60
            + time_value.minute
        )

    except:
        return np.nan

# %%
df_clean["Departure_Minutes"] = (
    df_clean["Departure_Time"]
    .apply(convert_time_to_minutes)
)

# %%
df_clean["Departure_Hour"] = (
    df_clean["Departure_Minutes"] // 60
)

# %%
df_clean[
    [
        "Departure_Time",
        "Departure_Hour",
        "Departure_Minutes"
    ]
].head(15)
# Out:
#    Departure_Time  Departure_Hour  Departure_Minutes
# 0         8:10 PM            20.0             1210.0
# 1           12:10            12.0              730.0
# 2         5:05 PM            17.0             1025.0
# 3           07:05             7.0              425.0
# 4        10:40 PM            22.0             1360.0
# 5         4:15 AM             4.0              255.0
# 6         1:35 AM             1.0               95.0
# 7         9:55 AM             9.0              595.0
# 8         5:45 AM             5.0              345.0
# 9         8:15 AM             8.0              495.0
# 10          13:30            13.0              810.0
# 11          23:30            23.0             1410.0
# 12          22:50            22.0             1370.0
# 13          19:25            19.0             1165.0
# 14          13:50            13.0              830.0

# %%
df_clean["Arrival_Minutes"] = (
    df_clean["Arrival_Time"]
    .apply(convert_time_to_minutes)
)

# %%
df_clean["Arrival_Hour"] = (
    df_clean["Arrival_Minutes"] // 60
)

# %%
df_clean[
    [
        "Arrival_Time",
        "Arrival_Hour",
        "Arrival_Minutes"
    ]
].head(15)
# Out:
#    Arrival_Time  Arrival_Hour  Arrival_Minutes
# 0         21:50          21.0           1310.0
# 1         12:55          12.0            775.0
# 2       7:53 AM           7.0            473.0
# 3      10:16 AM          10.0            616.0
# 4         12:36          12.0            756.0
# 5         21:02          21.0           1262.0
# 6       3:02 AM           3.0            182.0
# 7       3:21 PM          15.0            921.0
# 8         22:49          22.0           1369.0
# 9      11:35 AM          11.0            695.0
# 10        16:26          16.0            986.0
# 11        04:04           4.0            244.0
# 12        23:48          23.0           1428.0
# 13      4:54 PM          16.0           1014.0
# 14        15:51          15.0            951.0

# %% [markdown]
# converting duration represented by diff format to minutes

# %%
def convert_duration_to_minutes(value):

    if pd.isna(value):
        return np.nan

    value = str(value).strip().lower()

    try:

        # Format: 3h 11m
        if "h" in value:

            hour_part = value.split("h")[0].strip()
            hours = float(hour_part)

            minutes = 0

            if "m" in value:
                minute_part = value.split("h")[1]
                minute_part = (
                    minute_part
                    .replace("m", "")
                    .strip()
                )

                if minute_part:
                    minutes = float(minute_part)

            return hours * 60 + minutes

        # Format: 177 min
        elif "min" in value:

            return float(
                value.replace("min", "").strip()
            )

        # Decimal hours: 1.67
        else:

            return float(value) * 60

    except:

        return np.nan

# %%
df_clean["Duration_Minutes"] = (
    df_clean["Duration"]
    .apply(convert_duration_to_minutes)
)

# %%
df_clean[
    [
        "Duration",
        "Duration_Minutes"
    ]
].head(30)
# Out:
#     Duration  Duration_Minutes
# 0       1.67             100.2
# 1     0h 45m              45.0
# 2      14.80             888.0
# 3     3h 11m             191.0
# 4      13.93             835.8
# 5    16h 47m            1007.0
# 6     1h 28m              88.0
# 7     5h 27m             327.0
# 8    17h 04m            1024.0
# 9     3h 20m             200.0
# 10   177 min             177.0
# 11       NaN               NaN
# 12    0h 59m              59.0
# 13       NaN               NaN
# 14    2h 02m             122.0
# 15   155 min             155.0
# 16   22h 40m            1360.0
# 17   18h 45m            1125.0
# 18    6h 04m             364.0
# 19      1.98             118.8
# 20    2h 38m             158.0
# 21       NaN               NaN
# 22      4.38             262.8
# 23   900 min             900.0
# 24  1039 min            1039.0
# 25    0h 49m              49.0
# 26    3h 27m             207.0
# 27   20h 26m            1226.0
# 28    2h 16m             136.0
# 29    5h 41m             341.0

# %%
df_clean["Duration_Minutes"].describe()
# Out:
# count    93099.000000
# mean       488.028709
# std        358.837067
# min         45.000000
# 25%        198.000000
# 50%        354.000000
# 75%        731.000000
# max       1647.000000
# Name: Duration_Minutes, dtype: float64

# %%
def convert_stops(value):

    if pd.isna(value):
        return np.nan

    value = str(value).strip().lower()

    if value in ["non-stop", "non stop", "0"]:
        return 0

    value = (
        value
        .replace("stops", "")
        .replace("stop", "")
        .strip()
    )

    try:
        return float(value)

    except:
        return np.nan

# %%
df_clean["Total_Stops_Clean"] = (
    df_clean["Total_Stops"]
    .apply(convert_stops)
)

# %%
print(
    df_clean[
        [
            "Total_Stops",
            "Total_Stops_Clean"
        ]
    ].drop_duplicates()
    .sort_values("Total_Stops_Clean")
    .to_string(index=False)
)
# Out:
# Total_Stops  Total_Stops_Clean
#           0                0.0
#    non-stop                0.0
#      1 stop                1.0
#           1                1.0
#     2 stops                2.0
#           2                2.0
#         NaN                NaN

# %%
numeric_columns = [
    "Distance_km",
    "Days_Before_Departure",
    "Passenger_Count",
    "Price"
]

for column in numeric_columns:

    df_clean[column] = pd.to_numeric(
        df_clean[column],
        errors="coerce"
    )

# %%
df_clean[numeric_columns].dtypes
# Out:
# Distance_km              float64
# Days_Before_Departure    float64
# Passenger_Count          float64
# Price                    float64
# dtype: object

# %% [markdown]
# segregating feature engineered columns

# %%
engineered_columns = [
    "Journey_Year",
    "Journey_Month",
    "Journey_Day",
    "Journey_DayOfWeek",
    "Departure_Hour",
    "Departure_Minutes",
    "Arrival_Hour",
    "Arrival_Minutes",
    "Duration_Minutes",
    "Total_Stops_Clean"
]

df_clean[engineered_columns].head()
# Out:
#    Journey_Year  Journey_Month  Journey_Day  Journey_DayOfWeek  \
# 0        2025.0            8.0          2.0                5.0
# 1        2025.0            6.0          5.0                3.0
# 2        2025.0            2.0         11.0                1.0
# 3        2025.0            4.0         19.0                5.0
# 4        2026.0            7.0          5.0                6.0
#
#    Departure_Hour  Departure_Minutes  Arrival_Hour  Arrival_Minutes  \
# 0            20.0             1210.0          21.0           1310.0
# 1            12.0              730.0          12.0            775.0
# 2            17.0             1025.0           7.0            473.0
# 3             7.0              425.0          10.0            616.0
# 4            22.0             1360.0          12.0            756.0
#
#    Duration_Minutes  Total_Stops_Clean
# 0             100.2                0.0
# 1              45.0                0.0
# 2             888.0                1.0
# 3             191.0                1.0
# 4             835.8                0.0

# %%
missing_after_engineering = (
    df_clean.isnull().sum()
    .sort_values(ascending=False)
)

print(missing_after_engineering)
# Out:
# Price                    7781
# Distance_km              7595
# Passenger_Count          6690
# Days_Before_Departure    6067
# Duration                 4940
# Duration_Minutes         4940
# Booking_Channel          4871
# Journey_Month            4842
# Journey_Year             4842
# Journey_Day              4842
# Journey_DayOfWeek        4842
# Departure_Date           4842
# Total_Stops_Clean        4821
# Total_Stops              4821
# Source                   4815
# Airline                  4788
# Destination              4784
# Departure_Hour           4773
# Departure_Minutes        4773
# Departure_Time           4773
# Travel_Class             4763
# Aircraft_Type            4755
# Arrival_Hour             4701
# Arrival_Time             4701
# Arrival_Minutes          4701
# Season                   4689
# Weekday                  4619
# Flight_ID                   0
# dtype: int64

# %%
print(df_clean["Duration_Minutes"].describe())
print(df_clean["Travel_Class"].value_counts(dropna=False))
# Out:
# count    93099.000000
# mean       488.028709
# std        358.837067
# min         45.000000
# 25%        198.000000
# 50%        354.000000
# 75%        731.000000
# max       1647.000000
# Name: Duration_Minutes, dtype: float64
# Travel_Class
# Economy            63604
# Premium Economy    14770
# Business           11030
# <NA>                4763
# First               3872
# Name: count, dtype: Int64

# %% [markdown]
# segregating columns that have categorical entries and checking for null entries

# %%
categorical_columns = [
    "Airline",
    "Source",
    "Destination",
    "Travel_Class",
    "Season",
    "Weekday",
    "Aircraft_Type",
    "Booking_Channel"
]

for column in categorical_columns:
    df_clean[column] = (
        df_clean[column]
        .astype("string")
        .fillna("Unknown")
    )

# %%
for column in categorical_columns:
    print(f"\n{column}")
    print(df_clean[column].value_counts(dropna=False))
# Out:
# Airline
# Airline
# Singapore Airlines    8772
# Lufthansa             8663
# Etihad Airways        8614
# Thai Airways          8576
# Emirates              8570
# Qatar Airways         8503
# British Airways       8456
# Vistara               6287
# Air India             6198
# Airasia India         5182
# Indigo                5176
# Gofirst               5142
# Spicejet              5112
# Unknown               4788
# Name: count, dtype: Int64
#
# Source
# Source
# Unknown              4815
# Chennai              3456
# Pune                 3431
# Doha                 3427
# Singapore            3426
# New York             3412
# Hyderabad            3406
# Bangkok              3405
# Dubai                3396
# Frankfurt            3393
# Ahmedabad            3391
# Bangalore            3382
# Jaipur               3370
# Mumbai               3364
# Sydney               3363
# London               3332
# Kolkata              3315
# Delhi                3299
# Goa                  3283
# Goi                   965
# Jaipur Airport        945
# Bkk                   937
# Del                   935
# Dxb                   932
# Ahmedabad Airport     930
# Bom                   925
# Kolkata Airport       919
# Blr                   918
# Lhr                   916
# Dubai Airport         914
# Jfk                   913
# Maa                   910
# Hyd                   908
# Sin                   904
# Mumbai Airport        903
# New York Airport      902
# Delhi Airport         900
# Hyderabad Airport     900
# Pune Airport          898
# Frankfurt Airport     894
# Amd                   894
# London Airport        894
# Sydney Airport        893
# Bangalore Airport     888
# Syd                   881
# Pnq                   879
# Bangkok Airport       879
# Ccu                   879
# Chennai Airport       878
# Doh                   877
# Singapore Airport     877
# Jai                   866
# Goa Airport           847
# Doha Airport          841
# Fra                   832
# Name: count, dtype: Int64
#
# Destination
# Destination
# Unknown              4784
# Bangkok              3427
# Goa                  3426
# Hyderabad            3420
# Pune                 3413
# Ahmedabad            3411
# London               3377
# Doha                 3366
# Delhi                3364
# Bangalore            3354
# Mumbai               3350
# Chennai              3347
# Kolkata              3333
# Singapore            3324
# Dubai                3322
# Frankfurt            3320
# Sydney               3316
# Jaipur               3303
# New York             3248
# Dubai Airport         959
# Singapore Airport     954
# Blr                   953
# New York Airport      951
# Goa Airport           951
# Bangkok Airport       941
# Goi                   932
# Del                   930
# Jai                   929
# Jaipur Airport        928
# Jfk                   928
# Maa                   925
# Dxb                   925
# Bom                   923
# Bangalore Airport     923
# Ccu                   923
# Mumbai Airport        920
# Doha Airport          916
# Chennai Airport       914
# London Airport        914
# Syd                   911
# Delhi Airport         911
# Sydney Airport        910
# Lhr                   910
# Amd                   905
# Bkk                   898
# Doh                   894
# Pune Airport          894
# Fra                   892
# Kolkata Airport       892
# Hyd                   873
# Pnq                   873
# Frankfurt Airport     872
# Ahmedabad Airport     862
# Sin                   854
# Hyderabad Airport     844
# Name: count, dtype: Int64
#
# Travel_Class
# Travel_Class
# Economy            63604
# Premium Economy    14770
# Business           11030
# Unknown             4763
# First               3872
# Name: count, dtype: Int64
#
# Season
# Season
# Monsoon    31189
# Summer     23606
# Winter     22838
# Autumn     15717
# Unknown     4689
# Name: count, dtype: Int64
#
# Weekday
# Weekday
# Sunday       13559
# Saturday     13336
# Tuesday      13328
# Wednesday    13323
# Thursday     13320
# Friday       13279
# Monday       13275
# Unknown       4619
# Name: count, dtype: Int64
#
# Aircraft_Type
# Aircraft_Type
# Airbus A320              20057
# Boeing 777               13273
# Airbus A350              13205
# Boeing 787 Dreamliner    13173
# Airbus A380              13064
# Airbus A321               6878
# ATR 72                    6821
# Boeing 737                6813
# Unknown                   4755
# Name: count, dtype: Int64
#
# Booking_Channel
# Booking_Channel
# Website            30071
# Mobile App         27835
# Travel Agent       16721
# Third-Party        13067
# Airport Counter     5474
# Unknown             4871
# Name: count, dtype: Int64

# %% [markdown]
# segregating columns with numerical entries and filling missing values with their medians

# %%
numerical_features = [
    "Distance_km",
    "Passenger_Count",
    "Days_Before_Departure",
    "Duration_Minutes",
    "Total_Stops_Clean",
    "Departure_Hour",
    "Departure_Minutes",
    "Arrival_Hour",
    "Arrival_Minutes",
    "Journey_Year",
    "Journey_Month",
    "Journey_Day",
    "Journey_DayOfWeek"
]

# %%
medians = df_clean[numerical_features].median()

print(medians)
# Out:
# Distance_km              3213.5
# Passenger_Count             2.0
# Days_Before_Departure      19.0
# Duration_Minutes          354.0
# Total_Stops_Clean           1.0
# Departure_Hour             12.0
# Departure_Minutes         720.0
# Arrival_Hour               11.0
# Arrival_Minutes           719.0
# Journey_Year             2026.0
# Journey_Month               7.0
# Journey_Day                16.0
# Journey_DayOfWeek           3.0
# dtype: float64

# %%
for column in numerical_features:
    df_clean[column] = (
        df_clean[column]
        .fillna(df_clean[column].median())
    )

# %%
print(
    df_clean[numerical_features]
    .isnull()
    .sum()
)
# Out:
# Distance_km              0
# Passenger_Count          0
# Days_Before_Departure    0
# Duration_Minutes         0
# Total_Stops_Clean        0
# Departure_Hour           0
# Departure_Minutes        0
# Arrival_Hour             0
# Arrival_Minutes          0
# Journey_Year             0
# Journey_Month            0
# Journey_Day              0
# Journey_DayOfWeek        0
# dtype: int64

# %%
print(
    df_clean[categorical_columns]
    .isnull()
    .sum()
)
# Out:
# Airline            0
# Source             0
# Destination        0
# Travel_Class       0
# Season             0
# Weekday            0
# Aircraft_Type      0
# Booking_Channel    0
# dtype: int64

# %% [markdown]
# prices has been choosed as the target and creating model dataset with no null price values

# %%
print("Missing prices:", df_clean["Price"].isnull().sum())
# Out:
# Missing prices: 7781

# %%
model_df = df_clean[
    df_clean["Price"].notna()
].copy()

# %%
print("Original cleaned rows:", len(df_clean))
print("Rows with known price:", len(model_df))
# Out:
# Original cleaned rows: 98039
# Rows with known price: 90258

# %%
print("Rows:", model_df.shape[0])
print("Columns:", model_df.shape[1])

print("\nRemaining missing values:")
print(
    model_df.isnull()
    .sum()
    .sort_values(ascending=False)
)
# Out:
# Rows: 90258
# Columns: 28
#
# Remaining missing values:
# Duration                 4532
# Departure_Date           4472
# Total_Stops              4427
# Departure_Time           4427
# Arrival_Time             4326
# Source                      0
# Airline                     0
# Flight_ID                   0
# Destination                 0
# Distance_km                 0
# Travel_Class                0
# Days_Before_Departure       0
# Season                      0
# Weekday                     0
# Aircraft_Type               0
# Booking_Channel             0
# Passenger_Count             0
# Price                       0
# Journey_Year                0
# Journey_Month               0
# Journey_Day                 0
# Journey_DayOfWeek           0
# Departure_Minutes           0
# Departure_Hour              0
# Arrival_Minutes             0
# Arrival_Hour                0
# Duration_Minutes            0
# Total_Stops_Clean           0
# dtype: int64

# %%
cleaned_file_path = (
    "/content/drive/MyDrive/flight_cleaned.csv"
)

df_clean.to_csv(
    cleaned_file_path,
    index=False
)

print("Cleaned dataset saved to:")
print(cleaned_file_path)
# Out:
# Cleaned dataset saved to:
# /content/drive/MyDrive/flight_cleaned.csv

# %%
model_file_path = (
    "/content/drive/MyDrive/flight_model_data.csv"
)

model_df.to_csv(
    model_file_path,
    index=False
)

print("Model dataset saved to:")
print(model_file_path)
# Out:
# Model dataset saved to:
# /content/drive/MyDrive/flight_model_data.csv

# %% [markdown]
# we are choosing calculated weekday feature over original due to inconsistencies with the original weekdays

# %%
comparison = pd.DataFrame({
    "Original_Weekday": df_clean["Weekday"],
    "Calculated_Weekday": df_clean["Departure_Date"].dt.day_name()
})

comparison.head(20)
# Out:
#    Original_Weekday Calculated_Weekday
# 0          Saturday           Saturday
# 1          Thursday           Thursday
# 2           Tuesday            Tuesday
# 3          Saturday           Saturday
# 4            Sunday             Sunday
# 5         Wednesday          Wednesday
# 6            Sunday             Sunday
# 7          Thursday           Thursday
# 8            Monday             Monday
# 9            Monday             Monday
# 10           Sunday             Sunday
# 11          Tuesday            Tuesday
# 12         Thursday           Thursday
# 13           Sunday             Sunday
# 14        Wednesday          Wednesday
# 15           Friday             Friday
# 16          Unknown            Tuesday
# 17         Saturday           Saturday
# 18         Saturday           Saturday
# 19        Wednesday          Wednesday

# %%
comparison["Match"] = (
    comparison["Original_Weekday"]
    .str.lower()
    ==
    comparison["Calculated_Weekday"]
    .str.lower()
)

print(comparison["Match"].value_counts(dropna=False))
# Out:
# Match
# True     88814
# <NA>      4842
# False     4383
# Name: count, dtype: Int64

# %%
print(model_df.shape)
# Out:
# (90258, 28)

# %%
print(
    model_df.isnull().sum()
    .sort_values(ascending=False)
)
# Out:
# Duration                 4532
# Departure_Date           4472
# Total_Stops              4427
# Departure_Time           4427
# Arrival_Time             4326
# Source                      0
# Airline                     0
# Flight_ID                   0
# Destination                 0
# Distance_km                 0
# Travel_Class                0
# Days_Before_Departure       0
# Season                      0
# Weekday                     0
# Aircraft_Type               0
# Booking_Channel             0
# Passenger_Count             0
# Price                       0
# Journey_Year                0
# Journey_Month               0
# Journey_Day                 0
# Journey_DayOfWeek           0
# Departure_Minutes           0
# Departure_Hour              0
# Arrival_Minutes             0
# Arrival_Hour                0
# Duration_Minutes            0
# Total_Stops_Clean           0
# dtype: int64

# %%
print(comparison["Match"].value_counts(dropna=False))
# Out:
# Match
# True     88814
# <NA>      4842
# False     4383
# Name: count, dtype: Int64

# %%
model_features = [
    "Airline",
    "Source",
    "Destination",
    "Duration_Minutes",
    "Total_Stops_Clean",
    "Distance_km",
    "Travel_Class",
    "Days_Before_Departure",
    "Season",
    "Aircraft_Type",
    "Booking_Channel",
    "Passenger_Count",
    "Journey_Year",
    "Journey_Month",
    "Journey_Day",
    "Journey_DayOfWeek",
    "Departure_Hour",
    "Arrival_Hour"
]

# %% [markdown]
# defining features for the model and the target

# %%
X = model_df[model_features].copy()

y = model_df["Price"].copy()
print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (90258, 18)
# Target shape: (90258,)

# %%
print(X.dtypes)
# Out:
# Airline                  string[python]
# Source                   string[python]
# Destination              string[python]
# Duration_Minutes                float64
# Total_Stops_Clean               float64
# Distance_km                     float64
# Travel_Class             string[python]
# Days_Before_Departure           float64
# Season                   string[python]
# Aircraft_Type            string[python]
# Booking_Channel          string[python]
# Passenger_Count                 float64
# Journey_Year                    float64
# Journey_Month                   float64
# Journey_Day                     float64
# Journey_DayOfWeek               float64
# Departure_Hour                  float64
# Arrival_Hour                    float64
# dtype: object

# %%
import matplotlib.pyplot as plt

airline_price = (
    model_df
    .groupby("Airline")["Price"]
    .mean()
    .sort_values(ascending=False)
)

print(airline_price)
# Out:
# Airline
# Qatar Airways         101218.814695
# Singapore Airlines    100557.631600
# Etihad Airways        100368.639326
# Emirates               99962.419490
# British Airways        99815.269909
# Thai Airways           99579.491549
# Lufthansa              98799.870113
# Unknown                73250.876730
# Air India              45521.445734
# Vistara                45149.312103
# Spicejet               10923.135554
# Airasia India          10884.289871
# Indigo                 10651.725695
# Gofirst                10206.177465
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(12, 6))

airline_price.plot(kind="bar")

plt.title("Average Flight Price by Airline")
plt.xlabel("Airline")
plt.ylabel("Average Price")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

airline_price.plot(kind="bar")

plt.title("Average Flight Price by Airline")
plt.xlabel("Airline")
plt.ylabel("Average Price")
plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(
    "/content/drive/MyDrive/flightwise_airline_price.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
import os

project_path = "/content/drive/MyDrive/Flight-AI"

os.makedirs(project_path, exist_ok=True)

print("Project folder:", project_path)
# Out:
# Project folder: /content/drive/MyDrive/Flight-AI

# %%
os.makedirs(
    f"{project_path}/notebooks",
    exist_ok=True
)

os.makedirs(
    f"{project_path}/src",
    exist_ok=True
)

os.makedirs(
    f"{project_path}/reports/figures",
    exist_ok=True
)

print("Project structure created.")
# Out:
# Project structure created.
